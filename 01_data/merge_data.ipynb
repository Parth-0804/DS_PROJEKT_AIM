# %%
import pandas as pd
import numpy as np

# %%
df_matches = pd.read_csv("matches.csv")
df_deliveries = pd.read_csv("deliveries.csv")

# df_auction = pd.read_csv("auction.csv")

# %%
df_deliveries.shape
# Out:
# (260920, 17)

# %%
df_matches.shape
# Out:
# (1095, 20)

# %%
df_deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
df_deliveries['id'] = df_deliveries['match_id']

# %%
df_del = df_deliveries.drop(columns='match_id')

# %%
(df_del.id.dtype)
# Out:
# dtype('int64')

# %%
df_matches.id.dtype
# Out:
# dtype('int64')

# %%
merged_df = pd.merge(df_del,df_matches, on='id',how='outer' )

# %%
merged_df.shape
# Out:
# (260920, 36)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   inning            260920 non-null  int64
#  1   batting_team      260920 non-null  object
#  2   bowling_team      260920 non-null  object
#  3   over              260920 non-null  int64
#  4   ball              260920 non-null  int64
#  5   batter            260920 non-null  object
#  6   bowler            260920 non-null  object
#  7   non_striker       260920 non-null  object
#  8   batsman_runs      260920 non-null  int64
#  9   extra_runs        260920 non-null  int64
#  10  total_runs        260920 non-null  int64
#  11  extras_type       14125 non-null   object
#  12  is_wicket         260920 non-null  int64
#  13  player_dismissed  12950 non-null   object
#  14  dismissal_kind    12950 non-null   object
#  15  fielder           9354 non-null    object
#  16  id                260920 non-null  int64
#  17  season            260920 non-null  object
#  18  city              248523 non-null  object
#  19  date              260920 non-null  object
#  20  match_type        260920 non-null  object
#  21  player_of_match   260430 non-null  object
#  22  venue             260920 non-null  object
#  23  team1             260920 non-null  object
#  24  team2             260920 non-null  object
#  25  toss_winner       260920 non-null  object
#  26  toss_decision     260920 non-null  object
#  27  winner            260430 non-null  object
#  28  result            260920 non-null  object
#  29  result_margin     256796 non-null  float64
#  30  target_runs       260611 non-null  float64
#  31  target_overs      260611 non-null  float64
#  32  super_over        260920 non-null  object
#  33  method            3646 non-null    object
#  34  umpire1           260920 non-null  object
#  35  umpire2           260920 non-null  object
# dtypes: float64(3), int64(8), object(25)
# memory usage: 71.7+ MB

# %%
df = merged_df.copy()

# %%
df.fillna(value=0)
# Out:
#         inning           batting_team                 bowling_team  over  \
# 0            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# ...        ...                    ...                          ...   ...
# 260915       2  Kolkata Knight Riders          Sunrisers Hyderabad     9
# 260916       2  Kolkata Knight Riders          Sunrisers Hyderabad     9
# 260917       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
# 260918       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
# 260919       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
#
#         ball       batter         bowler  non_striker  batsman_runs  \
# 0          1   SC Ganguly        P Kumar  BB McCullum             0
# 1          2  BB McCullum        P Kumar   SC Ganguly             0
# 2          3  BB McCullum        P Kumar   SC Ganguly             0
# 3          4  BB McCullum        P Kumar   SC Ganguly             0
# 4          5  BB McCullum        P Kumar   SC Ganguly             0
# ...      ...          ...            ...          ...           ...
# 260915     5      SS Iyer     AK Markram      VR Iyer             1
# 260916     6      VR Iyer     AK Markram      SS Iyer             1
# 260917     1      VR Iyer  Shahbaz Ahmed      SS Iyer             1
# 260918     2      SS Iyer  Shahbaz Ahmed      VR Iyer             1
# 260919     3      VR Iyer  Shahbaz Ahmed      SS Iyer             1
#
#         extra_runs  ...  toss_decision                 winner   result  \
# 0                1  ...          field  Kolkata Knight Riders     runs
# 1                0  ...          field  Kolkata Knight Riders     runs
# 2                1  ...          field  Kolkata Knight Riders     runs
# 3                0  ...          field  Kolkata Knight Riders     runs
# 4                0  ...          field  Kolkata Knight Riders     runs
# ...            ...  ...            ...                    ...      ...
# 260915           0  ...            bat  Kolkata Knight Riders  wickets
# 260916           0  ...            bat  Kolkata Knight Riders  wickets
# 260917           0  ...            bat  Kolkata Knight Riders  wickets
# 260918           0  ...            bat  Kolkata Knight Riders  wickets
# 260919           0  ...            bat  Kolkata Knight Riders  wickets
#
#        result_margin target_runs target_overs  super_over method  \
# 0              140.0       223.0         20.0           N      0
# 1              140.0       223.0         20.0           N      0
# 2              140.0       223.0         20.0           N      0
# 3              140.0       223.0         20.0           N      0
# 4              140.0       223.0         20.0           N      0
# ...              ...         ...          ...         ...    ...
# 260915           8.0       114.0         20.0           N      0
# 260916           8.0       114.0         20.0           N      0
# 260917           8.0       114.0         20.0           N      0
# 260918           8.0       114.0         20.0           N      0
# 260919           8.0       114.0         20.0           N      0
#
#               umpire1      umpire2
# 0           Asad Rauf  RE Koertzen
# 1           Asad Rauf  RE Koertzen
# 2           Asad Rauf  RE Koertzen
# 3           Asad Rauf  RE Koertzen
# 4           Asad Rauf  RE Koertzen
# ...               ...          ...
# 260915  J Madanagopal  Nitin Menon
# 260916  J Madanagopal  Nitin Menon
# 260917  J Madanagopal  Nitin Menon
# 260918  J Madanagopal  Nitin Menon
# 260919  J Madanagopal  Nitin Menon
#
# [260920 rows x 36 columns]

# %%
df.describe(include='all')
# Out:
#                inning    batting_team    bowling_team           over  \
# count   260920.000000          260920          260920  260920.000000
# unique            NaN              19              19            NaN
# top               NaN  Mumbai Indians  Mumbai Indians            NaN
# freq              NaN           31437           31505            NaN
# mean         1.483531             NaN             NaN       9.197677
# std          0.502643             NaN             NaN       5.683484
# min          1.000000             NaN             NaN       0.000000
# 25%          1.000000             NaN             NaN       4.000000
# 50%          1.000000             NaN             NaN       9.000000
# 75%          2.000000             NaN             NaN      14.000000
# max          6.000000             NaN             NaN      19.000000
#
#                  ball   batter    bowler non_striker   batsman_runs  \
# count   260920.000000   260920    260920      260920  260920.000000
# unique            NaN      673       530         663            NaN
# top               NaN  V Kohli  R Ashwin     V Kohli            NaN
# freq              NaN     6236      4679        6067            NaN
# mean         3.624486      NaN       NaN         NaN       1.265001
# std          1.814920      NaN       NaN         NaN       1.639298
# min          1.000000      NaN       NaN         NaN       0.000000
# 25%          2.000000      NaN       NaN         NaN       0.000000
# 50%          4.000000      NaN       NaN         NaN       1.000000
# 75%          5.000000      NaN       NaN         NaN       1.000000
# max         11.000000      NaN       NaN         NaN       6.000000
#
#            extra_runs  ...  toss_decision          winner   result  \
# count   260920.000000  ...         260920          260430   260920
# unique            NaN  ...              2              19        4
# top               NaN  ...          field  Mumbai Indians  wickets
# freq              NaN  ...         167471           34629   135296
# mean         0.067806  ...            NaN             NaN      NaN
# std          0.343265  ...            NaN             NaN      NaN
# min          0.000000  ...            NaN             NaN      NaN
# 25%          0.000000  ...            NaN             NaN      NaN
# 50%          0.000000  ...            NaN             NaN      NaN
# 75%          0.000000  ...            NaN             NaN      NaN
# max          7.000000  ...            NaN             NaN      NaN
#
#         result_margin    target_runs   target_overs  super_over method  \
# count   256796.000000  260611.000000  260611.000000      260920   3646
# unique            NaN            NaN            NaN           2      1
# top               NaN            NaN            NaN           N    D/L
# freq              NaN            NaN            NaN      257286   3646
# mean        17.279451     167.290406      19.846742         NaN    NaN
# std         21.600307      32.165944       1.224266         NaN    NaN
# min          1.000000      43.000000       5.000000         NaN    NaN
# 25%          6.000000     148.000000      20.000000         NaN    NaN
# 50%          8.000000     167.000000      20.000000         NaN    NaN
# 75%         20.000000     188.000000      20.000000         NaN    NaN
# max        146.000000     288.000000      20.000000         NaN    NaN
#
#              umpire1 umpire2
# count         260920  260920
# unique            62      62
# top     AK Chaudhary  S Ravi
# freq           27353   19983
# mean             NaN     NaN
# std              NaN     NaN
# min              NaN     NaN
# 25%              NaN     NaN
# 50%              NaN     NaN
# 75%              NaN     NaN
# max              NaN     NaN
#
# [11 rows x 36 columns]

# %%
teams_map = {'Royal Challengers Bangalore':'Bangalore'
              , 'Kings XI Punjab':'Punjab'
              , 'Delhi Daredevils':'Delhi'
              , 'Mumbai Indians':'Mumbai'
              , 'Kolkata Knight Riders':'Kolkata'
              , 'Rajasthan Royals':'Rajasthan'
              , 'Deccan Chargers':'Hyderabad'
              , 'Chennai Super Kings':'Chennai'
              , 'Kochi Tuskers Kerala':'Kerala'
              , 'Pune Warriors':'Pune'
              , 'Sunrisers Hyderabad':'Hyderabad'
              , 'Gujarat Lions':'Gujarat'
              , 'Rising Pune Supergiants':'Pune'
              , 'Rising Pune Supergiant':'Pune'
              , 'Delhi Capitals':'Delhi'
              , 'Punjab Kings':'Punjab'
              , 'Lucknow Super Giants':'Lucknow'
              , 'Gujarat Titans':'Gujarat'
              , 'Royal Challengers Bengaluru':'Bangalore'
}
for col in (df.columns):
    df[col] = df[col].apply(lambda x: teams_map.get(x, x))

# %%
df.describe(include='all')
# Out:
#                inning batting_team bowling_team           over           ball  \
# count   260920.000000       260920       260920  260920.000000  260920.000000
# unique            NaN           12           12            NaN            NaN
# top               NaN       Mumbai       Mumbai            NaN            NaN
# freq              NaN        31437        31505            NaN            NaN
# mean         1.483531          NaN          NaN       9.197677       3.624486
# std          0.502643          NaN          NaN       5.683484       1.814920
# min          1.000000          NaN          NaN       0.000000       1.000000
# 25%          1.000000          NaN          NaN       4.000000       2.000000
# 50%          1.000000          NaN          NaN       9.000000       4.000000
# 75%          2.000000          NaN          NaN      14.000000       5.000000
# max          6.000000          NaN          NaN      19.000000      11.000000
#
#          batter    bowler non_striker   batsman_runs     extra_runs  ...  \
# count    260920    260920      260920  260920.000000  260920.000000  ...
# unique      673       530         663            NaN            NaN  ...
# top     V Kohli  R Ashwin     V Kohli            NaN            NaN  ...
# freq       6236      4679        6067            NaN            NaN  ...
# mean        NaN       NaN         NaN       1.265001       0.067806  ...
# std         NaN       NaN         NaN       1.639298       0.343265  ...
# min         NaN       NaN         NaN       0.000000       0.000000  ...
# 25%         NaN       NaN         NaN       0.000000       0.000000  ...
# 50%         NaN       NaN         NaN       1.000000       0.000000  ...
# 75%         NaN       NaN         NaN       1.000000       0.000000  ...
# max         NaN       NaN         NaN       6.000000       7.000000  ...
#
#         toss_decision  winner   result  result_margin    target_runs  \
# count          260920  260430   260920  256796.000000  260611.000000
# unique              2      12        4            NaN            NaN
# top             field  Mumbai  wickets            NaN            NaN
# freq           167471   34629   135296            NaN            NaN
# mean              NaN     NaN      NaN      17.279451     167.290406
# std               NaN     NaN      NaN      21.600307      32.165944
# min               NaN     NaN      NaN       1.000000      43.000000
# 25%               NaN     NaN      NaN       6.000000     148.000000
# 50%               NaN     NaN      NaN       8.000000     167.000000
# 75%               NaN     NaN      NaN      20.000000     188.000000
# max               NaN     NaN      NaN     146.000000     288.000000
#
#          target_overs  super_over method       umpire1 umpire2
# count   260611.000000      260920   3646        260920  260920
# unique            NaN           2      1            62      62
# top               NaN           N    D/L  AK Chaudhary  S Ravi
# freq              NaN      257286   3646         27353   19983
# mean        19.846742         NaN    NaN           NaN     NaN
# std          1.224266         NaN    NaN           NaN     NaN
# min          5.000000         NaN    NaN           NaN     NaN
# 25%         20.000000         NaN    NaN           NaN     NaN
# 50%         20.000000         NaN    NaN           NaN     NaN
# 75%         20.000000         NaN    NaN           NaN     NaN
# max         20.000000         NaN    NaN           NaN     NaN
#
# [11 rows x 36 columns]

# %%
print(f"We have {df[df['inning']>2].winner.nunique()} matches which went to super over")
# Out:
# We have 7 matches which went to super over

# %%
merged_df.to_csv("merged_matches&devlieries.csv")
